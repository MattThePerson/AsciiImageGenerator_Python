# %%
import matplotlib.pylab as plt
from skimage import io
from skimage import data
import numpy as np
import math
from PIL import Image
from PIL import ImageDraw
from PIL import ImageFont

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10, 5) # width and height

# %%
#image = io.imread("Lenna.png")
image = data.astronaut()

# variable type
print('variable type:', type(image) )

# data type
print('data type:', image.dtype)    

# print array shape/dimensions
print('array shape:', image.shape)  

# print number of array dimensions
print('number of dimensions:', image.ndim)  

# print number of elements in the array.
print('number of elements:', image.size)  

print(image[10,10])
# Out:
# variable type: <class 'numpy.ndarray'>
# data type: uint8
# array shape: (512, 512, 3)
# number of dimensions: 3
# number of elements: 786432
# [59 57 86]

# %%
image[10,10] = [0,255,0]
fig, ax = plt.subplots()
ax.imshow(image)
ax.axis('off')
# Out:
# (-0.5, 511.5, 511.5, -0.5)

# %%
def rgb2gray(img):
    return 0.2125*image[:,:,0] + 0.7154*image[:,:,1] + 0.0721*image[:,:,2]

# %%
red = image[:,:,0]
green = image[:,:,1]
blue = image[:,:,2]

gray = rgb2gray(image)

fig, ax = plt.subplots(1,4,figsize=(15,15))

ax[0].imshow(red, cmap=plt.cm.gray)
ax[0].set_title("red")
ax[0].axis('off')
ax[1].imshow(green, cmap=plt.cm.gray)
ax[1].set_title("green")
ax[1].axis('off')
ax[2].imshow(blue, cmap=plt.cm.gray)
ax[2].set_title("blue")
ax[2].axis('off')
ax[3].imshow(gray, cmap=plt.cm.gray)
ax[3].set_title("gray")
ax[3].axis('off')
# Out:
# (-0.5, 511.5, 511.5, -0.5)

# %%
def convertImgToBlocks(img, size=8):
    pass

# %%
shape = (345, 728)

size_w = 64
size_h = 32

w, h = gray.shape
w, h = math.floor(w/size_w), math.floor(w/size_h)
print(w, h)

blocks = np.empty((h, w, size_h, size_w))
print(blocks.shape)

for J in range(h):
    for I in range(w):
        new_block = np.zeros((size_h, size_w))
        y_start, x_start = J*size_h, I*size_w
        for j in range(size_h):
            for i in range(size_w):
                new_block[j][i] = gray[y_start+j][x_start+i]
        blocks[J][I] = new_block

#print(blocks[0][0])

fig, ax = plt.subplots()

ax.imshow(blocks[0][0], cmap=plt.cm.gray)
ax.axis('off')
# Out:
# 8 16
# (16, 8, 32, 64)
# (-0.5, 63.5, 31.5, -0.5)

# %%
sentence = ""
for x in range(32,127): sentence += chr(x)

print(sentence)
# Out:
#  !"#$%&'()*+,-./0123456789:;<=>?@ABCDEFGHIJKLMNOPQRSTUVWXYZ[\]^_`abcdefghijklmnopqrstuvwxyz{|}~

# %%
img = Image.open('white.png')

I1 = ImageDraw.Draw(img)

myFont = ImageFont.truetype('FreeMono.ttf', 65)

I1.text((0,0), sentence, font=myFont, fill=0)

print(img.getdata())

img.show()

print(type(img))
print(img.format)
print(img.save)
print(img.mode)

data = np.asarray(img)

print(type(data))

fig, ax = plt.subplots()

ax.imshow(data)
ax.axis('off')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[13], line 5
#       1 img = Image.open('white.png')
#       3 I1 = ImageDraw.Draw(img)
# ----> 5 myFont = ImageFont.truetype('FreeMono.ttf', 65)
#       7 I1.text((0,0), sentence, font=myFont, fill=0)
#       9 print(img.getdata())
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\PIL\ImageFont.py:791, in truetype(font, size, index, encoding, layout_engine)
#     788     return FreeTypeFont(font, size, index, encoding, layout_engine)
#     790 try:
# --> 791     return freetype(font)
#     792 except OSError:
#     793     if not is_path(font):
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\PIL\ImageFont.py:788, in truetype.<locals>.freetype(font)
#     787 def freetype(font):
# --> 788     return FreeTypeFont(font, size, index, encoding, layout_engine)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\PIL\ImageFont.py:226, in FreeTypeFont.__init__(self, font, size, index, encoding, layout_engine)
#     224                 load_from_bytes(f)
#     225             return
# --> 226     self.font = core.getfont(
#     227         font, size, index, encoding, layout_engine=layout_engine
#     228     )
#     229 else:
#     230     load_from_bytes(font)
#
# OSError: cannot open resource
